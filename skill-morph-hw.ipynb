# %% [markdown]
# <a href="https://www.kaggle.com/code/musabbir22/skill-morph-hw?scriptVersionId=255053052" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
#Disk Scheduling Algorithm
queue = [98,183,37,122,14,124,65,67]
path = []
head_start_pointer = 53
path.append(head_start_pointer)
total_distance = 0
for i in range(len(queue)):
  path.append(queue[i])
  total_distance = total_distance + abs(head_start_pointer - queue[i])
  head_start_pointer = queue[i]
print('path:',path)
print(f'Total Head Movement: {total_distance} cylinders')
# Out:
# path: [53, 98, 183, 37, 122, 14, 124, 65, 67]
# Total Head Movement: 640 cylinders
